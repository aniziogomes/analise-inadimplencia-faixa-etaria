# %%
# Importando Bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carregando Arquivo Excel
tabela = pd.read_excel(r"C:\Users\anizi\OneDrive\Documentos\Dados\bank_marketing.xlsx")

print(tabela.head()) # Mostrar as 5 primeiras linhas
# Out:
#    Unnamed: 0 Cliente_Comprou_o_Titulo?  Idade      Profissão Estado_Civil  \
# 0         NaN                       Não     33       Operário       Casado
# 1         NaN                       Não     58     Aposentado       Casado
# 2         NaN                       Sim     83     Aposentado       Casado
# 3         NaN                       Sim     32  Administrador     Solteiro
# 4         NaN                       Sim     31  Administrador     Solteiro
#
#           Formação Cliente_Devedor?  Saldo_Conta_Corrente Tem_Hipoteca?  \
# 0     Ensino Médio              Não                   263           Sim
# 1     Ensino Médio              Não                    19           Não
# 2      Fundamental              Não                   425           Não
# 3  Ensino Superior              Não                 10281           Não
# 4     Ensino Médio              Não                   360           Sim
#
#   Tem_Emprestimo?  Qte_de_Ligações_Feitas
# 0             Não                       3
# 1             Sim                       3
# 2             Não                       1
# 3             Não                       1
# 4             Não                       1

# %%
#informações Gerais da PLanilha
info = (tabela.info())

# Resumo Estatístico (média, mínimo, máximo)
missing_values = (tabela.describe())

# Verificando se há valores nulos em cada coluna
statistics = (tabela.isnull().sum())

info, missing_values, statistics
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9684 entries, 0 to 9683
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 0 non-null      float64
#  1   Cliente_Comprou_o_Titulo?  9684 non-null   object
#  2   Idade                      9684 non-null   int64
#  3   Profissão                  9684 non-null   object
#  4   Estado_Civil               9684 non-null   object
#  5   Formação                   9684 non-null   object
#  6   Cliente_Devedor?           9684 non-null   object
#  7   Saldo_Conta_Corrente       9684 non-null   int64
#  8   Tem_Hipoteca?              9684 non-null   object
#  9   Tem_Emprestimo?            9684 non-null   object
#  10  Qte_de_Ligações_Feitas     9684 non-null   int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 832.3+ KB
# (None,
#         Unnamed: 0        Idade  Saldo_Conta_Corrente  Qte_de_Ligações_Feitas
#  count         0.0  9684.000000           9684.000000             9684.000000
#  mean          NaN    41.235130           1706.046881                2.463445
#  std           NaN    12.110432           2749.931890                2.630583
#  min           NaN    18.000000              1.000000                1.000000
#  25%           NaN    32.000000            258.000000                1.000000
#  50%           NaN    38.000000            728.000000                2.000000
#  75%           NaN    49.000000           2007.000000                3.000000
#  max           NaN    95.000000          29340.000000               63.000000,
#  Unnamed: 0                   9684
#  Cliente_Comprou_o_Titulo?       0
#  Idade                           0
#  Profissão                       0
#  Estado_Civil                    0
#  Formação                        0
#  Cliente_Devedor?                0
#  Saldo_Conta_Corrente            0
#  Tem_Hipoteca?                   0
#  Tem_Emprestimo?                 0
#  Qte_de_Ligações_Feitas          0
#  dtype: int64)

# %%
# Extraindo a coluna irrelevante
tabela.limpeza = tabela.drop(columns=["Unnamed: 0"])

# verificando as mudanças
tabela.limpeza.head()
# Out:
# C:\Users\anizi\AppData\Local\Temp\ipykernel_6128\3845167570.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   tabela.limpeza = tabela.drop(columns=["Unnamed: 0"])
#   Cliente_Comprou_o_Titulo?  Idade      Profissão Estado_Civil  \
# 0                       Não     33       Operário       Casado
# 1                       Não     58     Aposentado       Casado
# 2                       Sim     83     Aposentado       Casado
# 3                       Sim     32  Administrador     Solteiro
# 4                       Sim     31  Administrador     Solteiro
#
#           Formação Cliente_Devedor?  Saldo_Conta_Corrente Tem_Hipoteca?  \
# 0     Ensino Médio              Não                   263           Sim
# 1     Ensino Médio              Não                    19           Não
# 2      Fundamental              Não                   425           Não
# 3  Ensino Superior              Não                 10281           Não
# 4     Ensino Médio              Não                   360           Sim
#
#   Tem_Emprestimo?  Qte_de_Ligações_Feitas
# 0             Não                       3
# 1             Sim                       3
# 2             Não                       1
# 3             Não                       1
# 4             Não                       1

# %% [markdown]
# <b> PROCESSO ETL</b> Excluindo coluna irrelevante

# %%
dataFrame = tabela

colunas_interesse = ["Idade", "Cliente_Devedor?"]
if all (coluna in dataFrame.columns for coluna in colunas_interesse):
    print("Colunas presentes")
else:
    raise ValueError("Faltam Colunas")
# Out:
# Colunas presentes

# %% [markdown]
# <b>Nota:</b> Extraindo apenas as colunas de interesse para análise ( Idade e Cliente Devedor )<br>

# %%
print("Estatísticas descritiva da idade:")
print(dataFrame["Idade"].describe())
# Out:
# Estatísticas descritiva da idade:
# count    9684.000000
# mean       41.235130
# std        12.110432
# min        18.000000
# 25%        32.000000
# 50%        38.000000
# 75%        49.000000
# max        95.000000
# Name: Idade, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(tabela["Idade"], kde=True, color="blue", bins=20)
plt.title("Distribuição de Idades", fontsize=16)
plt.xlabel("Idade", fontsize=12)
plt.ylabel("Frequência", fontsize=12)
plt.show()
# Out:
# C:\Users\anizi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# <b>Público Majoritário de idade:</b>
# A maior parte das pessoas está na faixa de 30 a 50 anos, com um pico próximo dos 30 anos, indica que é um público relativamente adulto.

# %%
# Estilo dos gráficos
sns.set(style="whitegrid")

# %%
devedores_proporcao = dataFrame["Cliente_Devedor?"].value_counts(normalize=True)
print("\nProporção de clietes devedores:")
print(devedores_proporcao)
# Out:
# Proporção de clietes devedores:
# Cliente_Devedor?
# Não    0.993288
# Sim    0.006712
# Name: proportion, dtype: float64

# %% [markdown]
# <b>Explicação das Proporções:</b> Indica que 99,3% dos clientes não são inadimplentes, enquanto apenas 0,67% são inadimplentes.

# %%
bins = [0, 25, 35, 50, 65, 100]
labels = ["0-25", "26-35", "36-50", "51-65", "65+"]
dataFrame["Faixa_Etaria"] = pd.cut(dataFrame["Idade"], bins=bins, labels=labels, right=False)

proporcao_devedores = dataFrame.groupby("Faixa_Etaria")["Cliente_Devedor?"].mean()

plt.figure(figsize=(8, 5))
proporcao_devedores.plot(kind='bar', color='coral', edgecolor='black')
plt.title("Proporção de Clientes Devedores por Faixa Etária", fontsize=14)
plt.xlabel("Faixa Etária", fontsize=12)
plt.ylabel("Proporção de Devedores", fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\anizi\AppData\Local\Temp\ipykernel_6128\426179676.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   proporcao_devedores = dataFrame.groupby("Faixa_Etaria")["Cliente_Devedor?"].mean()

# %% [markdown]
# <b> NOTA: </b> Conforme a idade avança, especialmente na faixa de 65 anos ou mais, a proporção de devedores diminui significativamente,
